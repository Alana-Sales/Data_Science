# %% [markdown]
# <a href="https://colab.research.google.com/github/Alana-Sales/Alana-Sales/blob/main/Bank_Churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 **Entrega #01: Análise Exploratória de Dados (EDA)**
# ### 🚀 Conjunto de Dados: Bank Churn (Rotatividade Bancária)
# **Metodologia:** CRISP-DM — Fase: Entendimento dos Dados
#
# ---
#
# ## 👥 **DataStorm**
# - Filipe Cayres Kelmer (cayresfilipe@gmail.com)
# - Maria Naiara Lima Flor (maria.naiara.lima@gmail.com)
# - Clara Alyne de Aguiar (claraalyneaguiar04@gmail.com)
# - Neiviene Costa (neive0009@gmail.com)
# - Alana Silva Sales (alanasilvasales37@gmail.com)

# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar visualizações
sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)

# Carregar dataset
url = 'https://raw.githubusercontent.com/atlantico-academy/datasets/refs/heads/main/churn.csv'
df = pd.read_csv(url)

# Visualizar as primeiras linhas
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# 📑 Dicionário de Dados - Análise Exploratória

import pandas as pd

df_dict = pd.DataFrame([
    {
        "Variável": "RowNumber",
        "Descrição": "Índice da linha no dataset (número sequencial).",
        "Tipo": "Quantitativa",
        "Subtipo": "Discreta",
        "Relevância": "Não útil"
    },
    {
        "Variável": "CustomerId",
        "Descrição": "Identificador único de cada cliente.",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Não útil"
    },
    {
        "Variável": "Surname",
        "Descrição": "Sobrenome do cliente.",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Não útil"
    },
    {
        "Variável": "CreditScore",
        "Descrição": "Pontuação de crédito do cliente.",
        "Tipo": "Quantitativa",
        "Subtipo": "Contínua",
        "Relevância": "Útil"
    },
    {
        "Variável": "Geography",
        "Descrição": "País de residência do cliente.",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Útil"
    },
    {
        "Variável": "Gender",
        "Descrição": "Sexo do cliente.",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Útil"
    },
    {
        "Variável": "Age",
        "Descrição": "Idade do cliente (em anos).",
        "Tipo": "Quantitativa",
        "Subtipo": "Contínua",
        "Relevância": "Útil"
    },
    {
        "Variável": "Tenure",
        "Descrição": "Tempo (em anos) que o cliente é fiel ao banco.",
        "Tipo": "Quantitativa",
        "Subtipo": "Discreta",
        "Relevância": "Útil"
    },
    {
        "Variável": "Balance",
        "Descrição": "Saldo disponível na conta bancária do cliente.",
        "Tipo": "Quantitativa",
        "Subtipo": "Contínua",
        "Relevância": "Útil"
    },
    {
        "Variável": "NumOfProducts",
        "Descrição": "Quantidade de produtos bancários adquiridos.",
        "Tipo": "Quantitativa",
        "Subtipo": "Discreta",
        "Relevância": "Útil"
    },
    {
        "Variável": "HasCrCard",
        "Descrição": "Possui cartão de crédito? (1 = Sim, 0 = Não)",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Útil"
    },
    {
        "Variável": "IsActiveMember",
        "Descrição": "Cliente é ativo? (1 = Sim, 0 = Não)",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Útil"
    },
    {
        "Variável": "EstimatedSalary",
        "Descrição": "Salário estimado do cliente (em moeda local).",
        "Tipo": "Quantitativa",
        "Subtipo": "Contínua",
        "Relevância": "Útil"
    },
    {
        "Variável": "Exited",
        "Descrição": "Cliente encerrou o relacionamento com o banco? (1 = Sim, 0 = Não).",
        "Tipo": "Qualitativa",
        "Subtipo": "Nominal",
        "Relevância": "Útil (variável alvo)"
    }
])

# Exibe o dicionário de dados
df_dict
# Out:
#            Variável                                          Descrição  \
# 0         RowNumber    Índice da linha no dataset (número sequencial).
# 1        CustomerId               Identificador único de cada cliente.
# 2           Surname                              Sobrenome do cliente.
# 3       CreditScore                   Pontuação de crédito do cliente.
# 4         Geography                     País de residência do cliente.
# 5            Gender                                   Sexo do cliente.
# 6               Age                        Idade do cliente (em anos).
# 7            Tenure     Tempo (em anos) que o cliente é fiel ao banco.
# 8           Balance     Saldo disponível na conta bancária do cliente.
# 9     NumOfProducts       Quantidade de produtos bancários adquiridos.
# 10        HasCrCard       Possui cartão de crédito? (1 = Sim, 0 = Não)
# 11   IsActiveMember                Cliente é ativo? (1 = Sim, 0 = Não)
# ...

# %% [markdown]
# ## 📑 Descrição dos Dados
#
# ### 📖 Dicionário de Dados
# | Variável            | Descrição                                              | Tipo         | Subtipo  | Relevância para Análise        |
# | ------------------- | ------------------------------------------------------ | ------------ | -------- | ------------------------------ |
# | **RowNumber**       | Índice da linha (número sequencial)                    | Quantitativa | Discreta | Não útil (identificador)       |
# | **CustomerId**      | Identificador único do cliente                         | Qualitativa  | Nominal  | Não útil (identificador)       |
# | **Surname**         | Sobrenome do cliente                                   | Qualitativa  | Nominal  | Não útil (sem valor analítico) |
# | **CreditScore**     | Pontuação de crédito do cliente                        | Quantitativa | Contínua | Útil                           |
# | **Geography**       | País de residência do cliente                          | Qualitativa  | Nominal  | Útil                           |
# | **Gender**          | Gênero do cliente                                      | Qualitativa  | Nominal  | Útil                           |
# | **Age**             | Idade do cliente                                       | Quantitativa | Contínua | Útil                           |
# | **Tenure**          | Tempo de permanência como cliente (anos)               | Quantitativa | Discreta | Útil                           |
# | **Balance**         | Saldo da conta bancária                                | Quantitativa | Contínua | Útil                           |
# | **NumOfProducts**   | Número de produtos bancários contratados               | Quantitativa | Discreta | Útil                           |
# | **HasCrCard**       | Possui cartão de crédito (1 = Sim, 0 = Não)            | Qualitativa  | Nominal  | Útil                           |
# | **IsActiveMember**  | É membro ativo (1 = Sim, 0 = Não)                      | Qualitativa  | Nominal  | Útil                           |
# | **EstimatedSalary** | Salário estimado do cliente                            | Quantitativa | Contínua | Útil                           |
# | **Exited**          | Indicador de saída (1 = Saiu do banco, 0 = Permaneceu) | Qualitativa  | Nominal  | Útil (variável alvo)

# %% [markdown]
# ## 📊 Análise Univariada
#
# Exploramos cada variável individualmente para entender distribuição e outliers.

# %%
# Estatísticas descritivas
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Histogramas para variáveis quantitativas
quant_vars = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

for var in quant_vars:
    plt.figure(figsize=(8,4))
    sns.histplot(df[var], kde=True, bins=30)
    plt.title(f'Distribuição de {var}')
    plt.show()

# %%
# Tabelas de frequência e contagens para qualitativas
qual_vars = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember', 'Exited']

for var in qual_vars:
    print(f'\nFrequência de {var}:\n')
    print(df[var].value_counts())
    sns.countplot(x=df[var])
    plt.title(f'Contagem de {var}')
    plt.show()
# Out:
# Frequência de Geography:
#
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# Frequência de Gender:
#
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64
# Frequência de HasCrCard:
#
# HasCrCard
# 1    7055
# 0    2945
# Name: count, dtype: int64
# Frequência de IsActiveMember:
#
# IsActiveMember
# 1    5151
# 0    4849
# Name: count, dtype: int64
# Frequência de Exited:
#
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# ## 🔗 Análise Bivariada
#
# Exploramos as relações entre pares de variáveis para identificar padrões.

# %%
# Matriz de correlação apenas para colunas numéricas
num_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10,8))
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm')
plt.title('Matriz de Correlação')
plt.show()

# %%
# Scatterplot Age vs Balance
sns.scatterplot(x='Age', y='Balance', hue='Exited', data=df)
plt.title('Idade vs. Saldo, colorido por Churn')
plt.show()

# Boxplot Balance por Geography
sns.boxplot(x='Geography', y='Balance', hue='Exited', data=df)
plt.title('Saldo por País e Churn')
plt.show()

# %% [markdown]
# ## 🔬 Análise Multivariada
#
# Analisamos interações entre três ou mais variáveis.

# %%
# Pairplot
sns.pairplot(df, vars=['Age', 'Balance', 'EstimatedSalary'], hue='Exited')
plt.show()

# %% [markdown]
# ## 📍 Principais Insights
#
# - Clientes mais velhos tendem a sair mais do banco (Churn maior com idade elevada).
# - A variável `Geography` mostra variações no churn — clientes da Alemanha saem mais.
# - Não há correlação forte entre salário estimado e churn.
# - A maioria dos clientes possui cartão de crédito, mas isso não garante retenção.
# - Clientes com apenas um produto bancário têm maior taxa de saída.
#
# ## 🧠 Hipóteses
#
# - Clientes com mais produtos têm menor propensão ao churn?
# - A inatividade do cliente contribui fortemente para a saída?
# - Há algum limite de idade a partir do qual o risco de churn aumenta significativamente?
